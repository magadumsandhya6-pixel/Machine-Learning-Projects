# %%
Roll No:CO-2105 and Name:Sandhya Raghunath Magadum

# %%
 Advance Data Type
1-List
2-Tuple
3-Set
4-Dictionary

# %%
#1-list example
fruits=["Apple","Banana","Mango"]
print (fruits)
print (fruits[1])
fruits.append("Orange")
print (fruits)
# Out:
# ['Apple', 'Banana', 'Mango']
# Banana
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
#2-Tuple example
fruit=("Apple","Orange","Mango")
print (fruit)
print (fruit[1])
# Out:
# ('Apple', 'Orange', 'Mango')
# Orange

# %%
#3-Set example
fruits={"Grapes","Papaya","Pineapple"}
print (fruits)
fruits.add("Watermealon")
print (fruits)
# Out:
# {'Grapes', 'Papaya', 'Pineapple'}
# {'Grapes', 'Papaya', 'Pineapple', 'Watermealon'}

# %%
#4-Dictionary example
student = {
    "name" : "Sandhya",
    "age" :18,
    "city" : "kolhapur"
 }
print(student)
print(student["name"])
# Out:
# {'name': 'Sandhya', 'age': 18, 'city': 'kolhapur'}
# Sandhya
